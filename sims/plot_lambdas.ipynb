# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
files = [f for f in os.listdir('./') if f.endswith('.csv')]

# %%
plt.subplots?

# %%
for f in files:
    df = pd.read_csv(f)
    fig, ax = plt.subplots(1,2, figsize=(2.1*8,8))
    ax[0].plot(df['lambda'].values, 'k')
    ax[1].hist(df['lambda'].values, normed=True)
    ax[1].vlines(df['lambda'].mean(), 0,1)
    print('{f} : {m} \t({v})'.format(f=f, m=df['lambda'].mean(), v=df['lambda'].var()))
    plt.show()
# Out:
# 0.8_n0.2.csv : -0.0296401535985 	(0.213100824979)
# 0.8_0.2.csv : 0.0687673823262 	(0.217549566548)
# 0.6_0.8.csv : 0.125501574984 	(0.21603983904)
# 0.8_n0.8.csv : -0.330891741083 	(0.19991095548)
# 0.8_n0.6.csv : -0.148006199938 	(0.222678982302)
# 0.8_0.0.csv : 0.0294096359036 	(0.212242635557)
# 0.8_n0.4.csv : -0.0532115778842 	(0.220331840254)
# 0.8_0.6.csv : 0.0954056159438 	(0.211646069214)
# 0.8_0.4.csv : 0.0849432905671 	(0.213250443134)
# 0.8_0.8.csv : 0.106547374526 	(0.208375740238)
# 0.6_0.6.csv : 0.100385796142 	(0.21405513074)
