# %%
import hlm
from hlm.abstracts import Trace
import pandas as pd
import numpy as np
import copy
# %matplotlib inline

# %%
Trace.from_csv('./hlm/tests/data/south_mvcm_5000', multi=True)

# %%
a = _

# %%
from hlm.diagnostics import psrf

# %%
psrf(trace=a)
# Out:
# {'Alphas': [1.0198343662576543,
#   1.0007518299780267,
#   1.007621455936957,
#   1.0367455272965691,
#   1.0021219212284864,
#   1.0113288697372356,
#   1.0001346382578733,
#   1.0038732738062277,
#   0.99999174945147495,
#   1.0004988415323972,
#   1.0280919175062282,
#   1.0039556592197179,
#   1.0333387719642824,
#   0.99995856727654353,
#   1.0449748011977684,
#   1.0091183851077761],
#  'Betas': [1.0277411181048948,
#   1.0000856404741971,
#   1.0003198206682236,
#   0.99992233062094338,
#   1.0390403692424779],
#  'Sigma2': 0.99996866484344427,
#  'Tau2': 1.0042780296894407}

# %%
a = _

# %%
a.drop('Unnamed: 0')

# %%
dfs = a.to_df()

# %%
dfs[0]
# Out:
#        Alphas_0  Alphas_1  Alphas_10  Alphas_11  Alphas_12  Alphas_13  \
# 0      0.294828 -1.030959  -0.329428   0.019068  -0.522486  -0.280756
# 1      0.601973 -0.159693  -0.147393   0.050597  -0.730060  -0.487003
# 2      0.399523  0.931742  -0.052878   0.137194  -0.539107  -0.622367
# 3      0.389212  1.070675  -0.215340  -0.041048  -0.396595  -0.487842
# 4      0.345274  1.262647  -0.308889   0.192069  -0.334999  -0.293588
# 5      0.297913  0.397946   0.000998   0.215692  -0.502789  -0.508598
# 6      0.375928  0.966377  -0.093516   0.123350  -0.247073  -0.592314
# 7      0.528238  0.821126  -0.645107   0.126424  -0.367484  -0.502294
# 8      0.286588  0.793344  -0.371260   0.001566  -0.304070  -0.603074
# 9      0.376883  0.767363  -0.625752   0.132166  -0.417520  -0.408053
# 10     0.518097  0.812455  -0.572070   0.030593  -0.501692  -0.411354
# 11     0.226585  0.875070  -0.420693  -0.063095  -0.546600  -0.498815
# ...

# %%
a.to_csv('./hlm/tests/data/south_mvcm_5000.csv')

# %%
Trace.from_csv('./hlm/tests/data/south_mvcm_5000', multi=True)

# %%
t = np.squeeze(a.chains[0]['Alphas']).shape

# %%
n,k = t[0:2]

# %%
rest = t[2:]

# %%
len(rest)
# Out:
# 0

# %%
import os

# %%
open('this isnnot real')
# Out:
# --------------------------------------------------------------------------
# FileNotFoundError                        Traceback (most recent call last)
# <ipython-input-4-4e007036e67c> in <module>()
# ----> 1 open('this isnnot real')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'this isnnot real'

# %%
FileNotFoundError
# Out:
# FileNotFoundError

# %%
a = _

# %%
del a.chains[0]['Unnamed: 0']

# %%
import pandas as pd

# %%
pd.DataFrame.to_csv?

# %%
df = pd.read_csv('./hlm/tests/data/south_mvcm_5000_0.csv')

# %%
Trace.from_csv('./hlm/tests/data/south_mvcm_5000', multi=True)
# Out:
# []

# %%
Trace.from_df(df).varnames
# Out:
# ['', 'Betas', 'Alphas']

# %%
['_'.join(s.split('_')) for s in df.columns]
# Out:
# ['Unnamed: 0',
#  'Lambda',
#  'Sigma2',
#  'Tau2',
#  'Alphas_0',
#  'Alphas_1',
#  'Alphas_2',
#  'Alphas_3',
#  'Alphas_4',
#  'Alphas_5',
#  'Alphas_6',
#  'Alphas_7',
#  'Alphas_8',
#  'Alphas_9',
#  'Alphas_10',
#  'Alphas_11',
#  'Alphas_12',
#  'Alphas_13',
#  'Alphas_14',
#  'Alphas_15',
#  'Betas_0',
#  'Betas_1',
#  'Betas_2',
#  'Betas_3',
#  'Betas_4',
#  'Betas_5']
