# %%
from hlm.hierarchical.msvcp import MSVC
from hlm.utils import baltim
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
model = MSVC(**baltim(), n_samples=0)
state = model.state

# %%
# %time model.sample(100, n_jobs=2)
# Out:
# CPU times: user 85 ms, sys: 34 ms, total: 119 ms
# Wall time: 29.7 s

# %%
data, df= baltim(df=True)

# %%
df[['AGE', 'SQFT', 'LOTSZ']] -
# Out:
#        AGE   SQFT   LOTSZ
# 0    148.0  11.25    5.70
# 1      9.0  28.92  279.51
# 2     23.0  30.62   70.64
# 3      5.0  26.12  174.63
# 4     19.0  22.04  107.80
# 5     20.0  39.42  139.64
# 6     20.0  21.88  250.00
# 7     22.0  36.72  100.00
# 8     22.0  25.60  115.90
# 9      4.0  44.12  365.07
# 10    23.0  19.88   81.10
# 11    20.0  12.08   91.00
# 12    30.0  10.99   74.35
# 13    20.0  13.60   46.17
# 14    18.0  12.80   23.10
# 15    75.0  29.79   14.40
# 16    60.0  14.30    8.97
# 17    65.0  13.72   10.22
# 18    14.0  11.84   38.89
# 19    45.0  18.06   70.00
# 20    14.0  10.72   70.82
# 21    22.0   8.96   18.39
# 22    35.0  14.38   73.25
# 23     5.0  36.75   56.12
# 24    60.0  20.00  400.37
# 25    14.0  22.82   87.96
# 26    19.0  24.86   70.40
# 27    11.0  19.20   84.00
# 28    16.0  11.58   52.55
# 29    19.0  26.00   77.76
# ..     ...    ...     ...
# 181   21.0  11.20   75.30
# 182    2.0  12.80   21.00
# 183   25.0  12.00   43.75
# ...

# %%
model.trace.plot()
plt.tight_layout()
plt.show()
# Out:
# /home/ljw/anaconda3/envs/py3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
